# %%
# %matplotlib inline

import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from sklearn.feature_extraction.text import TfidfVectorizer
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

np.set_printoptions(threshold=np.nan)

# %%
TRAIN_DATA_PATH = "../../train.csv"
TEST_DATA_PATH = "../../test.csv"
label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
comment_col = 'comment_text'
train = pd.read_csv(TRAIN_DATA_PATH)
test = pd.read_csv(TEST_DATA_PATH)
v = TfidfVectorizer()
msk = np.random.rand(len(train)) < 0.7
x = train[~msk]
train_ = train[msk]
msk = np.random.rand(len(x)) < 0.5
test_ = x[~msk]
valid_ = x[msk]

# %%
X_train = v.fit_transform(train_[comment_col])
Y_train = train_[label_cols].values
X_test = v.transform(valid_[comment_col])
Y_test = valid_[label_cols].values

# %%
lgb_train = {}
lgb_test = {}
for i,j in enumerate(label_cols):
    lgb_train[j] = lgb.Dataset(X_train,Y_train[:,i])
    lgb_test[j] = lgb.Dataset(X_test,Y_test[:,i],reference=lgb_train[j])

# %%
auc_xgb = {}
acc_xgb = {}
y_pred = {}

# %%
# specify your configurations as a dict
params = {'learning_rate': 0.2,
            'application': 'binary',
            'num_leaves': 31,
            'verbosity': -1,
            'metric': 'auc',
            'data_random_seed': 2,
            'bagging_fraction': 0.8,
            'feature_fraction': 0.6,
            'nthread': 4,
            'lambda_l1': 1,
            'lambda_l2': 1
         }
for j,i in enumerate(label_cols):
    print("Start Training for "+str(i))
    gbm = lgb.train(params, lgb_train[i], num_boost_round=20, valid_sets=lgb_test[i], early_stopping_rounds=5)
    print("Saving the model")
    gbm.save_model('model_'+str(i)+'.txt')
    print("Getting Predictions")
    y_pred[i] = gbm.predict(X_test, num_iteration=gbm.best_iteration)
    print('The rmse of prediction is:', mean_squared_error(Y_test[:,j], y_pred[i]) ** 0.5)
    auc_xgb[i] =  roc_auc_score(Y_test[:,j], y_pred[i])
    print("AUC for "+str(i)+" is "+str(auc_xgb[i]))
    print("\n\n")
# Out:
# Start Training for toxic
# [1]	valid_0's auc: 0.762788
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's auc: 0.828874
# [3]	valid_0's auc: 0.866898
# [4]	valid_0's auc: 0.892643
# [5]	valid_0's auc: 0.894773
# [6]	valid_0's auc: 0.903066
# [7]	valid_0's auc: 0.906259
# [8]	valid_0's auc: 0.908955
# [9]	valid_0's auc: 0.912861
# [10]	valid_0's auc: 0.917946
# [11]	valid_0's auc: 0.918471
# [12]	valid_0's auc: 0.920555
# [13]	valid_0's auc: 0.922369
# [14]	valid_0's auc: 0.9241
# [15]	valid_0's auc: 0.926662
# [16]	valid_0's auc: 0.928649
# [17]	valid_0's auc: 0.930418
# [18]	valid_0's auc: 0.929728
# [19]	valid_0's auc: 0.93138
# [20]	valid_0's auc: 0.932296
# Did not meet early stopping. Best iteration is:
# [20]	valid_0's auc: 0.932296
# Saving the model
# Getting Predictions
# The rmse of prediction is: 0.20528318256635625
# AUC for toxic is 0.9322964139760639
#
#
#
# Start Training for severe_toxic
# [1]	valid_0's auc: 0.854463
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's auc: 0.907107
# [3]	valid_0's auc: 0.95481
# [4]	valid_0's auc: 0.956512
# [5]	valid_0's auc: 0.9578
# [6]	valid_0's auc: 0.959654
# [7]	valid_0's auc: 0.963975
# [8]	valid_0's auc: 0.96466
# [9]	valid_0's auc: 0.96796
# [10]	valid_0's auc: 0.969651
# [11]	valid_0's auc: 0.970529
# [12]	valid_0's auc: 0.970327
# [13]	valid_0's auc: 0.970044
# [14]	valid_0's auc: 0.96997
# [15]	valid_0's auc: 0.971738
# [16]	valid_0's auc: 0.972722
# [17]	valid_0's auc: 0.972091
# [18]	valid_0's auc: 0.972313
# [19]	valid_0's auc: 0.97183
# [20]	valid_0's auc: 0.97314
# Did not meet early stopping. Best iteration is:
# [20]	valid_0's auc: 0.97314
# Saving the model
# Getting Predictions
# The rmse of prediction is: 0.0881824104968381
# AUC for severe_toxic is 0.9731403638767715
#
#
#
# Start Training for obscene
# [1]	valid_0's auc: 0.809225
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's auc: 0.901102
# [3]	valid_0's auc: 0.945049
# [4]	valid_0's auc: 0.953386
# [5]	valid_0's auc: 0.956387
# [6]	valid_0's auc: 0.960761
# [7]	valid_0's auc: 0.963469
# [8]	valid_0's auc: 0.967983
# [9]	valid_0's auc: 0.969335
# [10]	valid_0's auc: 0.970216
# [11]	valid_0's auc: 0.970887
# [12]	valid_0's auc: 0.973025
# [13]	valid_0's auc: 0.973504
# [14]	valid_0's auc: 0.97414
# [15]	valid_0's auc: 0.974109
# [16]	valid_0's auc: 0.973767
# [17]	valid_0's auc: 0.973771
# [18]	valid_0's auc: 0.974469
# [19]	valid_0's auc: 0.974167
# [20]	valid_0's auc: 0.974324
# Did not meet early stopping. Best iteration is:
# [18]	valid_0's auc: 0.974469
# Saving the model
# Getting Predictions
# The rmse of prediction is: 0.1344905260168948
# AUC for obscene is 0.9744690245018712
#
#
#
# Start Training for threat
# [1]	valid_0's auc: 0.631016
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's auc: 0.706857
# [3]	valid_0's auc: 0.799206
# [4]	valid_0's auc: 0.841623
# [5]	valid_0's auc: 0.841456
# [6]	valid_0's auc: 0.867835
# [7]	valid_0's auc: 0.87243
# [8]	valid_0's auc: 0.876578
# [9]	valid_0's auc: 0.880906
# [10]	valid_0's auc: 0.880742
# [11]	valid_0's auc: 0.880848
# [12]	valid_0's auc: 0.885765
# [13]	valid_0's auc: 0.889365
# [14]	valid_0's auc: 0.90483
# [15]	valid_0's auc: 0.912717
# [16]	valid_0's auc: 0.92669
# [17]	valid_0's auc: 0.930566
# [18]	valid_0's auc: 0.935225
# [19]	valid_0's auc: 0.934818
# [20]	valid_0's auc: 0.942601
# Did not meet early stopping. Best iteration is:
# [20]	valid_0's auc: 0.942601
# Saving the model
# Getting Predictions
# The rmse of prediction is: 0.05148131365487445
# AUC for threat is 0.942601484337826
#
#
#
# Start Training for insult
# [1]	valid_0's auc: 0.805412
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's auc: 0.879885
# [3]	valid_0's auc: 0.909751
# [4]	valid_0's auc: 0.930506
# [5]	valid_0's auc: 0.931184
# [6]	valid_0's auc: 0.938182
# [7]	valid_0's auc: 0.941675
# [8]	valid_0's auc: 0.944032
# [9]	valid_0's auc: 0.945546
# [10]	valid_0's auc: 0.946059
# [11]	valid_0's auc: 0.946687
# [12]	valid_0's auc: 0.947144
# [13]	valid_0's auc: 0.949108
# [14]	valid_0's auc: 0.950285
# [15]	valid_0's auc: 0.950158
# [16]	valid_0's auc: 0.951199
# [17]	valid_0's auc: 0.953419
# [18]	valid_0's auc: 0.953137
# [19]	valid_0's auc: 0.954341
# [20]	valid_0's auc: 0.954555
# Did not meet early stopping. Best iteration is:
# [20]	valid_0's auc: 0.954555
# Saving the model
# Getting Predictions
# The rmse of prediction is: 0.15482819547530005
# AUC for insult is 0.9545545705544919
#
#
#
# Start Training for identity_hate
# [1]	valid_0's auc: 0.7511
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's auc: 0.834577
# [3]	valid_0's auc: 0.875883
# [4]	valid_0's auc: 0.879149
# [5]	valid_0's auc: 0.882134
# [6]	valid_0's auc: 0.887784
# [7]	valid_0's auc: 0.88992
# [8]	valid_0's auc: 0.891838
# [9]	valid_0's auc: 0.891722
# [10]	valid_0's auc: 0.897758
# [11]	valid_0's auc: 0.919715
# [12]	valid_0's auc: 0.929397
# [13]	valid_0's auc: 0.932076
# [14]	valid_0's auc: 0.934885
# [15]	valid_0's auc: 0.936954
# [16]	valid_0's auc: 0.944403
# [17]	valid_0's auc: 0.943756
# [18]	valid_0's auc: 0.943993
# [19]	valid_0's auc: 0.945485
# [20]	valid_0's auc: 0.946122
# Did not meet early stopping. Best iteration is:
# [20]	valid_0's auc: 0.946122
# Saving the model
# Getting Predictions
# The rmse of prediction is: 0.0826348102571472
# AUC for identity_hate is 0.9461220960260291

# %% [markdown]
# Took Inspiration from:
# 1. [github documentation's sample code](https://github.com/Microsoft/LightGBM/blob/master/examples/python-guide/simple_example.py)
# 2. [Analytics Vidhya](https://www.analyticsvidhya.com/blog/2017/06/which-algorithm-takes-the-crown-light-gbm-vs-xgboost/#comment-152378)
# 3. NBSVM notebook
# 4. [Kaggle](https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge/discussion/52645)
